# %% [markdown]
# ## Instructions

# %% [markdown]
# We can skip the next cell if neural_de was installed from pip install.

# %%
import sys
sys.path.append("..")

# %% [markdown]
# Let's import neural_de

# %%
from neural_de.transformations import TransformationPipeline

# %% [markdown]
# We load an example image

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]= "TRUE"
import matplotlib.pyplot as plt
from pathlib import Path
import cv2

input_path = Path('../examples/images/night.jpg')
image = cv2.imread(str(input_path))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.title(image.shape)
# Out:
# Text(0.5, 1.0, '(427, 640, 3)')

# %% [markdown]
# # Pipeline configuration file format example

# %% [markdown]
# NeuralDe offers two ways to configure your pipeline, from a yaml file or directly from a list of parameters dict
# ### 1) Pipeline from a yaml file of the following structure :
#
# ---
#
#     name: ResolutionEnhancer
#         init_param:
#             device: 'cpu'
#         transform:
#           target_shape: [800, 800]
#           crop_ratio: .3
#     name: DesnowEnhancer
#
#  ---
# Please note that :
#
# - transform is for transformation parameters
# - init_param if for initialisation parameters
# - init_param and transform can be removed (as in DesnowEnhancer) if you want to use the defaults values for each method
#
# Let's see an example :

# %%
config_file = 'config/conf_user.yaml' # user configuration path

# %%
pipeline = TransformationPipeline(config_file)
res_image = pipeline.transform([image])
# Out:
# [11-06 11:50:03] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_twe_logger.py:123} INFO - Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# [11-06 11:50:03] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:55} INFO - Config loaded from config/conf_user.yaml loaded
# [11-06 11:50:03] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:35} INFO - Config file loaded
# [11-06 11:50:03] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:62} INFO - Loading all the pipeline methods and models
# [11-06 11:50:03] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_twe_logger.py:123} INFO - Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_night_image_enhancer.py:48} INFO - Model https://tfhub.dev/sayakpaul/maxim_s-2_enhancement_fivek/1 loaded
# INFO:neural_de_logger:Model https://tfhub.dev/sayakpaul/maxim_s-2_enhancement_fivek/1 loaded
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_twe_logger.py:123} INFO - Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# INFO:neural_de_logger:Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_derain_enhancer.py:55} INFO - Checking model availability...
# INFO:neural_de_logger:Checking model availability...
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_minio.py:65} INFO - Model already available locally, skipping download
# INFO:neural_de_logger:Model already available locally, skipping download
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_derain_enhancer.py:74} INFO - Trained model GT-rain loaded
# INFO:neural_de_logger:Trained model GT-rain loaded
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_twe_logger.py:123} INFO - Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# INFO:neural_de_logger:Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_desnow_enhancer.py:40} INFO - Checking model availability...
# INFO:neural_de_logger:Checking model availability...
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_minio.py:65} INFO - Model already available locally, skipping download
# INFO:neural_de_logger:Model already available locally, skipping download
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_desnow_enhancer.py:55} INFO - Loading model. Using cpu
# INFO:neural_de_logger:Loading model. Using cpu
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_desnow_enhancer.py:49} INFO - Model correctly loaded to cpu
# INFO:neural_de_logger:Model correctly loaded to cpu
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_twe_logger.py:123} INFO - Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# INFO:neural_de_logger:Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_twe_logger.py:123} INFO - Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# INFO:neural_de_logger:Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_resolution_enhancer.py:63} INFO - ResolutionEnhancer Initialized
# INFO:neural_de_logger:ResolutionEnhancer Initialized
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:81} INFO - All pipeline models successfully loaded
# INFO:neural_de_logger:All pipeline models successfully loaded
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:102} INFO - Applying method <neural_de.transformations._night_image_enhancer.NightImageEnhancer object at 0x000002634C8FF750> to images
# INFO:neural_de_logger:Applying method <neural_de.transformations._night_image_enhancer.NightImageEnhancer object at 0x000002634C8FF750> to images
# [11-06 11:51:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_night_image_enhancer.py:103} INFO - New image shape detected, readying model for size (448, 640)
# INFO:neural_de_logger:New image shape detected, readying model for size (448, 640)
# [11-06 11:52:02] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_night_image_enhancer.py:106} INFO - Model ready for image size (448, 640)
# INFO:neural_de_logger:Model ready for image size (448, 640)
# 1/1 [==============================] - 56s 56s/step
# [11-06 11:52:58] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:102} INFO - Applying method <neural_de.transformations._derain_enhancer.DeRainEnhancer object at 0x00000263EA4B4AD0> to images
# INFO:neural_de_logger:Applying method <neural_de.transformations._derain_enhancer.DeRainEnhancer object at 0x00000263EA4B4AD0> to images
# [11-06 11:53:21] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:102} INFO - Applying method <neural_de.transformations._desnow_enhancer.DeSnowEnhancer object at 0x00000263BE898690> to images
# INFO:neural_de_logger:Applying method <neural_de.transformations._desnow_enhancer.DeSnowEnhancer object at 0x00000263BE898690> to images
# [11-06 11:53:26] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:102} INFO - Applying method <neural_de.transformations._kernel_deblurring_enhancer.KernelDeblurringEnhancer object at 0x0000026368721DD0> to images
# INFO:neural_de_logger:Applying method <neural_de.transformations._kernel_deblurring_enhancer.KernelDeblurringEnhancer object at 0x0000026368721DD0> to images
# [11-06 11:53:26] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:102} INFO - Applying method <neural_de.transformations._resolution_enhancer.ResolutionEnhancer object at 0x00000263E92CC950> to images
# INFO:neural_de_logger:Applying method <neural_de.transformations._resolution_enhancer.ResolutionEnhancer object at 0x00000263E92CC950> to images
# [11-06 11:53:28] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_resolution_enhancer.py:72} INFO - Swin2 model loaded to cpu
# INFO:neural_de_logger:Swin2 model loaded to cpu

# %%
# show transformations final result
plt.imshow(res_image[0])
plt.title(res_image.shape)
# Out:
# Text(0.5, 1.0, '(1, 800, 800, 3)')

# %% [markdown]
# ## 2) Pipeline from a python list
#
# For a dynamic usage of NeuralDe pipelines, to perform automatic parameter search for example, or if you do not want to store the configuration on a local filesystem,
# you can directly provide the configuration as a list of each method name and parameters.
#
# Let's see an example :

# %%
conf = [{"name": 'ResolutionEnhancer', "transform": {'target_shape': [100, 100], 'crop_ratio': 0.5}},
        {"name": 'KernelDeblurringEnhancer', "init_param": {"kernel":"medium"}}]

# %% [markdown]
# As in the yaml syntax, if we only use the default parameters for initialization or transform, we can omit the corresponding fields.

# %%
pipeline = TransformationPipeline(conf)
res_image = pipeline.transform([image])
# Out:
# [11-06 11:57:33] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_twe_logger.py:123} INFO - Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# INFO:neural_de_logger:Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# [11-06 11:57:33] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:35} INFO - Config file loaded
# INFO:neural_de_logger:Config file loaded
# [11-06 11:57:33] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:62} INFO - Loading all the pipeline methods and models
# INFO:neural_de_logger:Loading all the pipeline methods and models
# [11-06 11:57:33] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_twe_logger.py:123} INFO - Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# INFO:neural_de_logger:Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# [11-06 11:57:33] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_resolution_enhancer.py:63} INFO - ResolutionEnhancer Initialized
# INFO:neural_de_logger:ResolutionEnhancer Initialized
# [11-06 11:57:33] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\utils\_twe_logger.py:123} INFO - Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# INFO:neural_de_logger:Logger: name: neural_de_logger, handlers: [<StreamHandler stdout (DEBUG)>]
# [11-06 11:57:33] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:81} INFO - All pipeline models successfully loaded
# INFO:neural_de_logger:All pipeline models successfully loaded
# [11-06 11:57:33] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:102} INFO - Applying method <neural_de.transformations._resolution_enhancer.ResolutionEnhancer object at 0x0000026363204C50> to images
# INFO:neural_de_logger:Applying method <neural_de.transformations._resolution_enhancer.ResolutionEnhancer object at 0x0000026363204C50> to images
# [11-06 11:57:35] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_resolution_enhancer.py:72} INFO - Swin2 model loaded to cpu
# INFO:neural_de_logger:Swin2 model loaded to cpu
# [11-06 11:57:37] {C:\Users\marc.lacourt\PycharmProjects\neuralde\examples\..\neural_de\transformations\_transformation_pipeline.py:102} INFO - Applying method <neural_de.transformations._kernel_deblurring_enhancer.KernelDeblurringEnhancer object at 0x00000263E969BE10> to images
# INFO:neural_de_logger:Applying method <neural_de.transformations._kernel_deblurring_enhancer.KernelDeblurringEnhancer object at 0x00000263E969BE10> to images

# %% [markdown]
# - Let's see the result :

# %%
plt.imshow(res_image[0])
plt.title(res_image[0].shape)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, '(100, 100, 3)')

# %% [markdown]
# - We made a pipeline for pixel art !
